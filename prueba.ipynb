# %%
import pandas as pd
import glob
import os
import re
from send2trash import send2trash
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import threading
import sys

# %%
df = pd.read_excel("subirUnigis-SALUD.xlsx")

dfconfig = pd.read_excel("condicionales.xlsx", index_col="Regla")["Valor"].to_dict()
